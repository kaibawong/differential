# %%
import pandas as pd
brdiff = pd.read_table('Historical marker crude prices_csv.csv',delimiter =';')
brdiff = brdiff.stack().str.replace(',','.').unstack()
brdiff=brdiff.fillna(0)
print(brdiff)

brdiff.dtypes
brdiff =brdiff.iloc[:,1:-1].astype(float)

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

brdiff["Dated Brent scaled"] = scaler.fit_transform(brdiff["Dated Brent"].to_frame())

import matplotlib.pyplot as plt  

plt.scatter(brdiff.iloc[:,0],brdiff.iloc[:,-1])
plt.show()

from sklearn import linear_model
import statsmodels.api as sm
#X = df[['Interest_Rate','Unemployment_Rate']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
#Y = df['Stock_Index_Price']
 
# with sklearn
#regr = linear_model.LinearRegression()
#regr.fit(X, Y)

AbsB=brdiff["Dated Brent"].max()
brdiff["Dated Brent norm"] = brdiff["Dated Brent"].divide(AbsB)
print(brdiff["Dated Brent norm"])

X = brdiff[['Dated Brent']]
Y = brdiff['Bonny light']
regr = linear_model.LinearRegression()
regr.fit(X, Y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)

New_DB = 19.5
New_M = -2.1
print ('Predicted BL: \n', regr.predict([[New_DB ]]))
# Out:
#            Date Dated Brent Bonny light Mars    WTI Maya Europe Maya USGC  \
# 0    01.01.2000        25.5           0    0      0           0         0
# 1    01.02.2000        27.9           0    0      0           0         0
# 2    01.03.2000        27.3           0    0      0           0         0
# 3    01.04.2000        22.6           0    0      0           0         0
# 4    01.05.2000        27.6           0    0      0           0         0
# ..          ...         ...         ...  ...    ...         ...       ...
# 231  01.04.2019        71.3         1.4  5.1   -7.4        -9.8      -6.5
# 232  01.05.2019        71.1         1.9  5.9  -10.3       -10.1      -8.4
# 233  01.06.2019        64.1         1.7  4.8   -9.4        -8.1      -5.2
# 234  01.07.2019        64.0         1.4  4.5   -6.5        -6.9      -4.1
# 235  01.08.2019        59.0         1.3  2.3   -4.2       -12.6      -8.0
#
#      ESPO Urals NWE Urals MED Dubai
# 0       0      -0.5      -0.5  -2.2
# 1       0      -0.5      -0.5  -3.2
# 2       0      -1.0      -1.5  -2.2
# 3       0      -1.0      -1.4  -0.5
# 4       0      -0.6      -1.2  -1.9
# ..    ...       ...       ...   ...
# 231   1.7      -0.1       0.4  -0.3
# 232   0.5      -0.9      -0.2  -1.7
# 233  -0.2      -2.7      -2.5  -2.3
# 234   2.3      -1.1      -0.5  -0.8
# 235   4.2      -0.1       1.2   0.1
#
# [236 rows x 11 columns]
# 0      0.191441
# 1      0.209459
# 2      0.204955
# 3      0.169670
# 4      0.207207
#          ...
# 231    0.535285
# 232    0.533784
# 233    0.481231
# 234    0.480480
# 235    0.442943
# Name: Dated Brent norm, Length: 236, dtype: float64
# Intercept:
#  -0.5207615785351083
# Coefficients:
#  [0.02636947]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Bonny light   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     370.7
# Date:                Wed, 04 Sep 2019   Prob (F-statistic):           3.80e-50
# Time:                        08:12:12   Log-Likelihood:                -226.59
# No. Observations:                 236   AIC:                             457.2
# Df Residuals:                     234   BIC:                             464.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.5208      0.098     -5.334      0.000      -0.713      -0.328
# Dated Brent     0.0264      0.001     19.254      0.000       0.024       0.029
# ==============================================================================
# Omnibus:                       26.279   Durbin-Watson:                   0.467
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.423
# Skew:                           0.690   Prob(JB):                     4.54e-09
# Kurtosis:                       4.416   Cond. No.                         168.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Predicted BL:
#  [-0.00655691]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
brdiff = pd.read_table('Historical marker crude prices_csv.csv',delimiter =';')
brdiff = brdiff.stack().str.replace(',','.').unstack()
brdiff=brdiff.fillna(0)
print(brdiff)

brdiff.dtypes
brdiff =brdiff.iloc[:,1:-1].astype(float)
B = brdiff.corr(method = 'kendall')

brdiff.corr(method = 'kendall')
# Out:
#            Date Dated Brent Bonny light Mars    WTI Maya Europe Maya USGC  \
# 0    01.01.2000        25.5           0    0      0           0         0
# 1    01.02.2000        27.9           0    0      0           0         0
# 2    01.03.2000        27.3           0    0      0           0         0
# 3    01.04.2000        22.6           0    0      0           0         0
# 4    01.05.2000        27.6           0    0      0           0         0
# ..          ...         ...         ...  ...    ...         ...       ...
# 231  01.04.2019        71.3         1.4  5.1   -7.4        -9.8      -6.5
# 232  01.05.2019        71.1         1.9  5.9  -10.3       -10.1      -8.4
# 233  01.06.2019        64.1         1.7  4.8   -9.4        -8.1      -5.2
# 234  01.07.2019        64.0         1.4  4.5   -6.5        -6.9      -4.1
# 235  01.08.2019        59.0         1.3  2.3   -4.2       -12.6      -8.0
#
#      ESPO Urals NWE Urals MED Dubai
# 0       0      -0.5      -0.5  -2.2
# 1       0      -0.5      -0.5  -3.2
# 2       0      -1.0      -1.5  -2.2
# 3       0      -1.0      -1.4  -0.5
# 4       0      -0.6      -1.2  -1.9
# ..    ...       ...       ...   ...
# 231   1.7      -0.1       0.4  -0.3
# 232   0.5      -0.9      -0.2  -1.7
# 233  -0.2      -2.7      -2.5  -2.3
# 234   2.3      -1.1      -0.5  -0.8
# 235   4.2      -0.1       1.2   0.1
#
# [236 rows x 11 columns]
#              Dated Brent  Bonny light      Mars       WTI  Maya Europe  \
# Dated Brent     1.000000     0.635932  0.218334 -0.343030    -0.438861
# Bonny light     0.635932     1.000000  0.093421 -0.209374    -0.325852
# Mars            0.218334     0.093421  1.000000 -0.636083    -0.269798
# WTI            -0.343030    -0.209374 -0.636083  1.000000     0.329003
# Maya Europe    -0.438861    -0.325852 -0.269798  0.329003     1.000000
# Maya USGC      -0.468963    -0.432499  0.122156  0.135352     0.331024
# ESPO            0.034447    -0.036314  0.162708 -0.237353    -0.216636
# Urals NWE      -0.046664    -0.069707  0.365254 -0.141969    -0.059903
# Urals MED       0.038156    -0.008551  0.352308 -0.231718    -0.228720
#
#              Maya USGC      ESPO  Urals NWE  Urals MED
# Dated Brent  -0.468963  0.034447  -0.046664   0.038156
# Bonny light  -0.432499 -0.036314  -0.069707  -0.008551
# Mars          0.122156  0.162708   0.365254   0.352308
# WTI           0.135352 -0.237353  -0.141969  -0.231718
# Maya Europe   0.331024 -0.216636  -0.059903  -0.228720
# Maya USGC     1.000000  0.082904   0.380327   0.258196
# ESPO          0.082904  1.000000   0.201719   0.322453
# Urals NWE     0.380327  0.201719   1.000000   0.756718
# Urals MED     0.258196  0.322453   0.756718   1.000000
